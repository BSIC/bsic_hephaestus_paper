# %%
import pandas as pd
import numpy as np
from wrds_api import connect_wrds

# %%
db = connect_wrds()
# Out:
# WRDS recommends setting up a .pgpass file.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
sorted(db.list_libraries())
# Out:
# ['aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_europe',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'block',
#  'block_all',
#  'boardex',
#  'boardex_eur',
#  'boardex_na',
#  'boardex_trial',
#  'boardex_uk',
#  'boardsmp',
#  'bvd_amadeus_trial',
#  'bvd_bvdbankf_trial',
#  'bvd_orbis_trial',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'cboe_sample',
#  'cboesamp',
#  'ciq',
#  'ciq_common',
#  'ciq_pplintel',
#  'ciqsamp',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'ciqsamp_ratings',
#  'ciqsamp_transactions',
#  'ciqsamp_transcripts',
#  'cisdmsmp',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_monthly_all',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
# ...

# %%
db.list_tables(library="wrdsapps_finratio")
# Out:
# ['firm_ratio', 'id']

# %%
db.describe_table(library="wrdsapps_finratio", table="firm_ratio")
# Out:
# Approximately 2794086 rows in wrdsapps_finratio.firm_ratio.
#            name  nullable              type comment
# 0         gvkey      True        VARCHAR(6)    None
# 1        permno      True           INTEGER    None
# 2         adate      True              DATE    None
# 3         qdate      True              DATE    None
# 4   public_date      True              DATE    None
# ..          ...       ...               ...     ...
# 93        ffi48      True  DOUBLE PRECISION    None
# 94   ffi49_desc      True        VARCHAR(5)    None
# 95        ffi49      True  DOUBLE PRECISION    None
# 96       ticker      True        VARCHAR(8)    None
# 97        cusip      True        VARCHAR(8)    None
#
# [98 rows x 4 columns]

# %%
permnos = (26825,)

sql_query = """
    SELECT * 
    FROM wrdsapps_finratio.firm_ratio 
    WHERE permno IN %(tickers)s AND adate >= '2010-01-01'
    LIMIT 10
"""

data = db.raw_sql(sql_query, params={"tickers": tuple(permnos)})
data
# Out:
#     gvkey  permno       adate       qdate public_date      capei      be  \
# 0  006375   26825  2010-12-31  2010-12-31  2011-02-28  17.110874  2855.0
# 1  006375   26825  2010-12-31  2010-12-31  2011-03-31  17.322988  2855.0
# 2  006375   26825  2010-12-31  2010-12-31  2011-04-30  18.378798  2855.0
# 3  006375   26825  2010-12-31  2011-03-31  2011-05-31  18.068186  3058.0
# 4  006375   26825  2010-12-31  2011-03-31  2011-06-30  17.538727  3058.0
# 5  006375   26825  2010-12-31  2011-03-31  2011-07-31  17.684565  3058.0
# 6  006375   26825  2010-12-31  2011-06-30  2011-08-31  17.010310  3242.0
# 7  006375   26825  2010-12-31  2011-06-30  2011-09-30  16.656450  3242.0
# 8  006375   26825  2010-12-31  2011-06-30  2011-10-31  16.975863  3242.0
# 9  006375   26825  2010-12-31  2011-09-30  2011-11-30  15.159109  3073.0
#
#          bm        evm  pe_op_basic  ...  ffi30_desc  ffi30  ffi38_desc  \
# 0  0.152878   9.924527    15.435159  ...        FOOD    1.0        FOOD
# ...

# %%
db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 db.close()
#
# NameError: name 'db' is not defined
